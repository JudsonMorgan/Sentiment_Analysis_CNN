# %%
from keras.layers import LSTM, Dense, Embedding
from keras.models import Sequential
from keras.preprocessing import sequence
from keras.datasets import imdb

# %%
#load the datasets
(X_train, y_train),(X_test, y_test) = imdb.load_data(num_words=20000)
#using the preprocessing pad_sequence function to reduce the features
X_train = sequence.pad_sequences(X_train, maxlen=100)
X_test = sequence.pad_sequences(X_test, maxlen=100)

# %%
X_train
# Out:
# array([[1415,   33,    6, ...,   19,  178,   32],
#        [ 163,   11, 3215, ...,   16,  145,   95],
#        [1301,    4, 1873, ...,    7,  129,  113],
#        ...,
#        [  11,    6, 4065, ...,    4, 3586,    2],
#        [ 100, 2198,    8, ...,   12,    9,   23],
#        [  78, 1099,   17, ...,  204,  131,    9]], dtype=int32)

# %%
X_test
# Out:
# array([[   0,    0,    0, ...,   14,    6,  717],
#        [   6,  976, 2078, ...,  125,    4, 3077],
#        [   4, 5673,    7, ...,    9,   57,  975],
#        ...,
#        [   0,    0,    0, ...,   21,  846, 5518],
#        [   0,    1,   11, ..., 2302,    7,  470],
#        [  56,   96,  346, ...,   34, 2005, 2643]], dtype=int32)

# %%
y_test
# Out:
# array([0, 1, 1, ..., 0, 0, 0])

# %%
#creating the neaural network
model = Sequential()
model.add(Embedding(20000, 128))
model.add(LSTM(128, dropout = 0.2, recurrent_dropout= 0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
#compile the model
model.compile(loss = 'binary_crossentropy',
              optimizer='adam',
              metrics = ['accuracy'])

# %%
#fit the model
model.fit(X_train,y_train,
          batch_size=32,
          epochs=10,
          verbose=2,
          validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 782/782 - 274s - loss: 0.4231 - accuracy: 0.8012 - val_loss: 0.3900 - val_accuracy: 0.8270 - 274s/epoch - 351ms/step
# Epoch 2/10
# 782/782 - 272s - loss: 0.2445 - accuracy: 0.9028 - val_loss: 0.3991 - val_accuracy: 0.8212 - 272s/epoch - 348ms/step
# Epoch 3/10
# 782/782 - 269s - loss: 0.1630 - accuracy: 0.9384 - val_loss: 0.4282 - val_accuracy: 0.8362 - 269s/epoch - 344ms/step
# Epoch 4/10
# 782/782 - 263s - loss: 0.1071 - accuracy: 0.9607 - val_loss: 0.6650 - val_accuracy: 0.8256 - 263s/epoch - 337ms/step
# Epoch 5/10
# 782/782 - 264s - loss: 0.0712 - accuracy: 0.9756 - val_loss: 0.5457 - val_accuracy: 0.8240 - 264s/epoch - 338ms/step
# Epoch 6/10
# 782/782 - 265s - loss: 0.0527 - accuracy: 0.9824 - val_loss: 0.6400 - val_accuracy: 0.8340 - 265s/epoch - 339ms/step
# Epoch 7/10
# 782/782 - 265s - loss: 0.0377 - accuracy: 0.9877 - val_loss: 0.7084 - val_accuracy: 0.8304 - 265s/epoch - 339ms/step
# Epoch 8/10
# 782/782 - 270s - loss: 0.0380 - accuracy: 0.9875 - val_loss: 0.8116 - val_accuracy: 0.8298 - 270s/epoch - 345ms/step
# Epoch 9/10
# 782/782 - 276s - loss: 0.0269 - accuracy: 0.9910 - val_loss: 0.7523 - val_accuracy: 0.8262 - 276s/epoch - 353ms/step
# Epoch 10/10
# 782/782 - 277s - loss: 0.0189 - accuracy: 0.9941 - val_loss: 0.8913 - val_accuracy: 0.8303 - 277s/epoch - 354ms/step

# %%
score, accuracy = model.evaluate(X_test, y_test, batch_size=32, verbose=2)
# Out:
# 782/782 - 26s - loss: 0.8913 - accuracy: 0.8303 - 26s/epoch - 33ms/step

# %%
model.predict(X_test)
# Out:
# array([[9.9633437e-01],
#        [9.9999678e-01],
#        [7.4445462e-01],
#        ...,
#        [3.2681227e-04],
#        [4.8641583e-01],
#        [9.9980497e-01]], dtype=float32)

# %%
y_pred = model.predict(X_test)
y_pred[:10]
# Out:
# array([[9.9633437e-01],
#        [9.9999678e-01],
#        [7.4445462e-01],
#        [5.7369679e-02],
#        [9.9999851e-01],
#        [9.9848688e-01],
#        [9.9812567e-01],
#        [4.0194540e-05],
#        [9.9980640e-01],
#        [9.9945295e-01]], dtype=float32)
